# %% [markdown]
# <h1><b><span style="color:skyblue">Explortory Data Analysis of Hotel Booking Data</span></b></h1>

# %% [markdown]
# <h2><span style="color:blue">Types of EDA</span></h2>

# %% [markdown]
# >1. Univariate Analysis
# >2. Bivariate Analysis
# >3. Multivariate Analysis
# >4. Time Series Analysis
# >5. Missing Data Analysis
# >6. Outliers Analysis

# %% [markdown]
# <h2><span style="color:blue">1. Loading File</span></h2>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option("display.max_column",24)

# %%
dataset=r"C:\Users\S A COMPUTER\Desktop\Data Science 2024\My Portfolio\Project 03 Python EDA, hotel booking cancellation\hotel_bookings 2.csv";
ds=pd.read_csv(dataset,skiprows=0)

# %% [markdown]
# <h2><span style="color:blue">2. Description of Data</span></h2>

# %% [markdown]
# <h3><span style="color:blue">Show selective rows</span></h3>

# %%
ds.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
ds.tail(n = 10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# <h3><span style="color:blue">Shap of the Data Set</span></h3>

# %%
ds.shape # Get the number of rows and columns
# Out:
# (119390, 32)

# %% [markdown]
# <h3><span style="color:blue">All Columns</span></h3>

# %%
ds.columns.tolist() # Get the list of a all columns
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %% [markdown]
# <h3><span style="color:blue">Summary Statistics of all Numeric Columns</span></h3>

# %%
#The .describe() method prints the summary statistics of all numeric columns, 
#such as count, mean, standard deviation, range, and quartiles of numeric columns.
ds.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# <h3><span style="color:blue">Understanding data using .info()</span></h3>

# %% [markdown]
# <ul>
# <li>The <b>.info()</b> method is a quick way to look at the data types, missing values, and data size of a DataFrame.</li>
# <li>Here, we’re setting the <b>show_counts argument to True</b>, which gives a few over the total non-missing values in each column.</li>
# <li>We’re also setting <b>memory_usage to True</b>, which shows the total memory usage of the DataFrame elements.</li>
# <li>When <b>verbose is set to True</b>, it prints the full summary from .info().</li>
# </ul>

# %%
ds.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#To Sum null values in each column
ds.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#To sum total null values in entire data 
ds.isnull().sum().sum()
# Out:
# 129425

# %% [markdown]
# <h2><span style="color:blue">3. Data Cleaning</span></h2>

# %% [markdown]
# <h3><span style="color:blue">1. To find null values in each column</span></h3>

# %%
#To Sum null values in each column
ds.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# <h3><span style="color:blue">2. Drop missing values</h3></span>

# %% [markdown]
# The default axis removes the rows containing NaNs. Use axis = 1 to remove the columns with one or more NaN values.

# %%
df = ds.copy()
df.drop(['agent','company'],inplace=True, axis=1)
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# <h3><span style="color:blue">3. describe data</h3></span>

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# <h3><span style="color:blue">4. Dealing with outliers</h3></span>

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
df=df[df['adr']<5000]

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %%
print(df[['adr']].isna().sum())
# Out:
# adr    0
# dtype: int64

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# <h3><span style="color:blue">5. changing column object type to datetime</h3></span>

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format='%d/%m/%Y', errors='coerce')

# %%
print(df['reservation_status_date'].unique())
print(df['reservation_status_date'].isna().sum())
# Out:
# <DatetimeArray>
# ['2015-07-01 00:00:00', '2015-07-02 00:00:00', '2015-07-03 00:00:00',
#  '2015-05-06 00:00:00', '2015-04-22 00:00:00', '2015-06-23 00:00:00',
#  '2015-07-05 00:00:00', '2015-07-06 00:00:00', '2015-07-07 00:00:00',
#  '2015-07-08 00:00:00',
#  ...
#  '2015-03-13 00:00:00', '2015-05-05 00:00:00', '2015-03-29 00:00:00',
#  '2015-06-10 00:00:00', '2015-04-27 00:00:00', '2014-10-17 00:00:00',
#  '2015-01-20 00:00:00', '2015-02-17 00:00:00', '2015-03-10 00:00:00',
#  '2015-03-23 00:00:00']
# Length: 926, dtype: datetime64[ns]
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118897 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118897 non-null  object
#  1   is_canceled                     118897 non-null  int64
#  2   lead_time                       118897 non-null  int64
#  3   arrival_date_year               118897 non-null  int64
#  4   arrival_date_month              118897 non-null  object
#  5   arrival_date_week_number        118897 non-null  int64
#  6   arrival_date_day_of_month       118897 non-null  int64
#  7   stays_in_weekend_nights         118897 non-null  int64
#  8   stays_in_week_nights            118897 non-null  int64
#  9   adults                          118897 non-null  int64
#  10  children                        118897 non-null  float64
#  11  babies                          118897 non-null  int64
# ...

# %% [markdown]
# <h3><span style="color:blue">6. Unique values</h3></span>

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'ROU' 'NOR' 'OMN' 'ARG' 'POL' 'DEU'
#  'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST' 'CZE'
#  'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR' 'UKR'
#  'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO' 'ISR'
#  'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM' 'HRV'
#  'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY' 'KWT'
#  'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN' 'SYC'
#  'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB' 'CMR'
# ...

# %% [markdown]
# <h2><span style="color:blue">15. Exploratory Data Analysis (EDA)</h2></span>

# %% [markdown]
# <h3><b>Revenue-Related Questions:</b></h3>

# %% [markdown]
# <b>Revenue Analysis:</b>
# <br>City-wise Revenue: Identify which cities generate the most revenue.
# <br>Monthly/Quarterly Revenue Trends: Analyze revenue trends over time to identify peak sales periods.
# <br>Product Category Revenue: Determine which product categories contribute the most to revenue.

# %% [markdown]
# <h4><b>Q no 1 : Percentage of cancelled booking?</b></h4>

# %%
# To check cancelled booking 
cancelled_per=df['is_canceled'].value_counts(normalize=True)
cancelled_per=cancelled_per*100
cancelled_per
# Out:
# is_canceled
# 0    62.865337
# 1    37.134663
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,4))
plt.title('Reservation status count')
plt.bar(['Not cancelled', 'Cancelled'], df['is_canceled'].value_counts(), edgecolor='k', width=0.5)
plt.show()

# %%
plt.figure(figsize=(5,4))
axl=sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
lagend_labels,_=axl.get_legend_handles_labels()
axl.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status in different hotels', size=20)
plt.xlabel('Hotel')
plt.ylabel('Number of Reservations')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Resort Hotel Price is more than city Hetels if compared 
#In resots EDR is main reason but in City Hotels there could be multiple reasons b

# %%
#Applying Filter to check Resort Hotel count as percenatge 
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    72.024952
# 1    27.975048
# Name: proportion, dtype: float64

# %%
#Applying Filter to check Resort Hotel count as percenatge 
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)*100
# Out:
# is_canceled
# 0    58.291825
# 1    41.708175
# Name: proportion, dtype: float64

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel'].groupby('reservation_status_date')[['adr']].mean()
city_hotel = df[df['hotel'] == 'City Hotel'].groupby('reservation_status_date')[['adr']].mean()
print(resort_hotel)
print(city_hotel)
# Out:
#                                 adr
# reservation_status_date
# 2014-11-18                 0.000000
# 2015-01-01                61.966667
# 2015-01-02                 9.633750
# 2015-01-18                 0.000000
# 2015-01-21                37.301209
# ...                             ...
# 2017-09-08               101.012500
# 2017-09-09               147.778333
# 2017-09-10               145.272500
# 2017-09-12               153.570000
# 2017-09-14               105.930000
#
# [913 rows x 1 columns]
#                                 adr
# reservation_status_date
# 2014-10-17                62.800000
# 2015-01-01                62.063158
# 2015-01-20                76.500000
# 2015-01-30                61.400000
# 2015-02-17                76.500000
# ...                             ...
# 2017-09-03               137.172600
# 2017-09-04               116.925385
# 2017-09-05               154.000000
# 2017-09-06                93.293333
# 2017-09-07               159.685000
#
# ...

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel', fontsize=30)
plt.plot(resort_hotel.index, resort_hotel['adr'], label='Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
# The City's orange line is center which shows that city hotel rates are low as campared to Resort hotels and there pikes in resort hotel plots 
#which shows that it increase on weekends

# %%
# Assuming 'reservation_status_date' is a list of dates
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# Now you can extract the month
df['month'] = df['reservation_status_date'].dt.month

plt.figure(figsize=(16,6))
axl=sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
lagend_labels,_=axl.get_legend_handles_labels()
axl.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status per month', size=20)
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.legend('canceled', 'not_canceled', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# >Based on this plot highest cancelation can be seen in the first month (January), and lowest in the eighth month (August)
# >On the other hand higest reservation are recorded in the  months of august and lowest in the month of december and january

# %%
plt.figure(figsize=(14, 5))
# Make sure to use the new syntax
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index(), width=0.6, palette='bright')
plt.title('Adr per month', size=30)
plt.show()

# %% [markdown]
# >Our Hypothesis is correct, As price increase cancellation also increase
# >
# >As in the month of January and july price is very high so cancelation is also high

# %%
cancelled_data=df[df['is_canceled']==1]
Top_10_countries=cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8, 8))
plt.title('Top 10 Countries with Reservation cancelled')
plt.pie(Top_10_countries, autopct='%0.2f', labels=Top_10_countries.index)
plt.show()

# %% [markdown]
# >Highest cancelation in 70% in portugal and GBR

# %%
#Checking market segemnt of reservation, is it online or offline 
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: proportion, dtype: float64

# %%
#Checking amrket share of cancelled data 
cancelled_data['market_segment'].value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        46.969560
# Groups           27.398532
# Offline TA/TO    18.746603
# Direct            4.348614
# Corporate         2.215075
# Complementary     0.203841
# Aviation          0.117775
# Name: proportion, dtype: float64

# %%
df['reservation_status_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 118897, dtype: datetime64[ns]

# %%
cancelled_df_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)  
cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2014-10-17   62.800000
# 1                2014-11-18    0.000000
# 2                2015-01-01   62.062779
# 3                2015-01-02    9.633750
# 4                2015-01-18    0.000000
# ..                      ...         ...
# 897              2017-08-26  178.200000
# 898              2017-08-27  167.300000
# 899              2017-08-28   81.416667
# 900              2017-08-29  144.253333
# 901              2017-08-31  189.750000
#
# [902 rows x 2 columns]

# %%
# For non-cancelled reservations
not_cancelled_data=df[df['is_canceled']==0]
not_cancelled_df_adr=not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr
# Out:
#     reservation_status_date         adr
# 0                2015-07-01   31.650000
# 1                2015-07-02   95.924000
# 2                2015-07-03   97.645205
# 3                2015-07-04  110.480000
# 4                2015-07-05  100.308485
# ..                      ...         ...
# 800              2017-09-08  101.012500
# 801              2017-09-09  147.778333
# 802              2017-09-10  145.272500
# 803              2017-09-12  153.570000
# 804              2017-09-14  105.930000
#
# [805 rows x 2 columns]

# %%
# Plotting
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate', fontsize='30')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label='Not Cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='Cancelled')
plt.legend()
plt.show()

# %%
#Filtering data 
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016') & (cancelled_df_adr['reservation_status_date']<'2017-09')]
not_cancelled_df_adr=not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016') & (not_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
# Plotting
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate', fontsize='30')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label='Not Cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='Cancelled')
plt.legend()
plt.show()
